# %%
import scipy.stats
import math

data=[8.6,9.4,7.9,8.3,6.8,7.3,9.2,9.6,8.7,11.4,10.3,5.4,8.1,5.5,6.9]
n=len(data)
print("Number of data points are=",n)

m=sum(data)/n
print("the mean of the data is= ",m)


s=scipy.stats.tstd(data)
print("Std of the data is=",s)

lower_bound=scipy.stats.t.ppf(0.025,n-1,loc=m,scale=s/math.sqrt(n))
upper_bound=scipy.stats.t.ppf(0.975,n-1,loc=m,scale=s/math.sqrt(n))

print("The lower bound=",lower_bound)
print("The Upper bound=",upper_bound)
# Out:
# Number of data points are= 15
# the mean of the data is=  8.226666666666667
# Std of the data is= 1.6722383060978339
# The lower bound= 7.300611959652363
# The Upper bound= 9.15272137368097

# %%
import scipy.stats
import math

data=[79,145,147,160,116,100,159,151,156,126,137,83,156,94,121,144,123,114,139,99]
n=len(data)
print('Total number in the data are',n)

m=sum(data)/n
print('the mean is',m)

s=scipy.stats.tstd(data)
print("The standard deviation is ",s)

lower_bound=scipy.stats.t.ppf(0.05,n-1,loc=m,scale=s/math.sqrt(n))
upper_bound=scipy.stats.t.ppf(0.95,n-1,loc=m,scale=s/math.sqrt(n))
print('The lower bound is',lower_bound)
print('THe upper bound is',upper_bound)
# Out:
# Total number in the data are 20
# the mean is 127.45
# The standard deviation is  25.964500055997508
# The lower bound is 117.41093378346815
# THe upper bound is 137.48906621653185
